# %%
#connect drive to Colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Download Java
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# %%
#Install Apache Spark with Hadoop
#!wget -q https://dlcdn.apache.org/spark/spark-3.2.0/spark-3.2.0-bin-hadoop3.2.tgz -P drive/MyDrive/Colab_Notebooks/Amazon_reviews/Resources

# %%
#unzip
# !tar xf drive/MyDrive/Colab_Notebooks/Amazon_reviews/Resources/spark-3.2.0-bin-hadoop3.2.tgz

# %%
# !pip install -q findspark

# %%
#set PySpark enviroment
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64" 
os.environ["SPARK_HOME"] = "/content/spark-3.2.0-bin-hadoop3.2"

# %%
#initate PySPark
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession
#create a Spark session
spark = SparkSession.builder\
        .master("local")\
        .appName("Colab")\
        .config('spark.ui.port', '4050')\
        .getOrCreate()
#print the SparkSession variable.
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://5841335cfc4e:4050">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Colab</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import pyspark
#from pyspark.sql.functions import isnan, when, count, col
import pyspark.sql.functions as F
from pyspark.sql.functions import col, trim, lower, regexp_replace

# %%
import numpy as np
import pandas as pd

# %%
filePath = "drive/MyDrive/Colab_Notebooks/Amazon_reviews/preprocess_data"
df = spark.read.json(filePath)
df.printSchema()
# Out:
# root
#  |-- categories: string (nullable = true)
#  |-- overall: double (nullable = true)
#  |-- reviewText: string (nullable = true)
#  |-- reviewerName: string (nullable = true)
#  |-- summary: string (nullable = true)
#  |-- verified: boolean (nullable = true)
#  |-- vote: double (nullable = true)

# %%
df.show()
# Out:
# +----------+-------+--------------------+--------------------+--------------------+--------+----+
# |categories|overall|          reviewText|        reviewerName|             summary|verified|vote|
# +----------+-------+--------------------+--------------------+--------------------+--------+----+
# |  Software|    5.0|As someone who ha...|   Loves Books in MD|Learn Adobe Photo...|   false|null|
# |  Software|    4.0|I've been running...|           Mindcrime|Great product, bu...|   false|14.0|
# |  Software|    1.0|December 13, 2008...|         James Smith|Amazon, PBJWORLD ...|   false| 5.0|
# |  Software|    2.0|I have been a Qui...|     Lance_big_daddy|Intuit has lost i...|   false|31.0|
# |  Software|    1.0|This is by far th...|              Deimos|        Garbage.....|   false|null|
# |  Software|    1.0|I have had Acroni...|                Mark|After image is ma...|   false|null|
# |  Software|    1.0|I've used Turbota...|        Torrey Pines|Very buggy this year|   false|null|
# |  Software|    3.0|the software on i...|MetalheadMissy an...|the software is g...|   false|null|
# |  Software|    5.0|Easy to install a...|   AverageGuyShopper|Easy to install, ...|   false|null|
# |  Software|    2.0|[These comments a...|         Tony Polito|Buggy as cr@p, un...|   false|14.0|
# |  Software|    5.0|This is the first...|             ratyoke|         Easy to use|   false|null|
# |  Software|    5.0|Here is a gem of ...|         Ivan W. Ong|Clean, easy to us...|   false| 2.0|
# |  Software|    4.0|For anyone who ha...|           Ty Arthur|A great place to ...|   false|null|
# |  Software|    3.0|f you like WIll F...|              Arnold|Funny, but I was ...|   false|null|
# |  Software|    3.0|Like many have sa...|      William Hardin|It is a shame the...|   false| 9.0|
# |  Software|    5.0|I honestly haven'...|        Robert Riggs|       WORDPERFECT 5|   false|null|
# |  Software|    4.0|When I originally...|            Sarah B.|Great Internet Pr...|   false|null|
# |  Software|    4.0|I've been using K...|         Gadget Geek|    Solid protection|   false|null|
# |  Software|    3.0|It is what it is....|        Megan Bostic|It's fine but not...|   false|null|
# |  Software|    5.0|I have been a big...|           Jeri Zerr|Classic video, au...|   false|null|
# +----------+-------+--------------------+--------------------+--------------------+--------+----+
# only showing top 20 rows

# %%
def sparkShape(dataFrame):
    return (dataFrame.count(), len(dataFrame.columns))

# %%
pyspark.sql.dataframe.DataFrame.shape = sparkShape
print(df.shape())
# Out:
# (67691433, 7)

# %%
df.printSchema()
# Out:
# root
#  |-- categories: string (nullable = true)
#  |-- overall: double (nullable = true)
#  |-- reviewText: string (nullable = true)
#  |-- reviewerName: string (nullable = true)
#  |-- summary: string (nullable = true)
#  |-- verified: boolean (nullable = true)
#  |-- vote: double (nullable = true)

# %%
def removePunctuation(column):
     return trim(lower(regexp_replace(column,'[^\sa-zA-Z0-9]', ''))).alias('stopped')

# %%
df = df.withColumn("reviewText_cleaned",removePunctuation(col("reviewText")))

# %%
df.select('reviewText_cleaned').show()
# Out:
# +--------------------+
# |  reviewText_cleaned|
# +--------------------+
# |as someone who ha...|
# |ive been running ...|
# |december 13 2008\...|
# |i have been a qui...|
# |this is by far th...|
# |i have had acroni...|
# |ive used turbotax...|
# |the software on i...|
# |easy to install a...|
# |these comments ar...|
# |this is the first...|
# |here is a gem of ...|
# |for anyone who ha...|
# |f you like will f...|
# |like many have sa...|
# |i honestly havent...|
# |when i originally...|
# |ive been using ka...|
# |it is what it is ...|
# |i have been a big...|
# +--------------------+
# only showing top 20 rows

# %%
df = df.withColumn("summary_cleaned",removePunctuation(col("summary")))

# %%
df.select('summary_cleaned').show()
# Out:
# +--------------------+
# |     summary_cleaned|
# +--------------------+
# |learn adobe photo...|
# |great product but...|
# |amazon pbjworld  ...|
# |intuit has lost i...|
# |             garbage|
# |after image is ma...|
# |very buggy this year|
# |the software is g...|
# |easy to install r...|
# |buggy as crp unle...|
# |         easy to use|
# |clean easy to use...|
# |a great place to ...|
# |funny but i was e...|
# |it is a shame the...|
# |       wordperfect 5|
# |great internet pr...|
# |    solid protection|
# |its fine but noth...|
# |classic video aud...|
# +--------------------+
# only showing top 20 rows

# %%
df.printSchema()
# Out:
# root
#  |-- categories: string (nullable = true)
#  |-- overall: double (nullable = true)
#  |-- reviewText: string (nullable = true)
#  |-- reviewerName: string (nullable = true)
#  |-- summary: string (nullable = true)
#  |-- verified: boolean (nullable = true)
#  |-- vote: double (nullable = true)
#  |-- reviewText_cleaned: string (nullable = true)
#  |-- summary_cleaned: string (nullable = true)

# %%
df = df.drop("reviewText","summary")

# %%
df.printSchema()
# Out:
# root
#  |-- categories: string (nullable = true)
#  |-- overall: double (nullable = true)
#  |-- reviewerName: string (nullable = true)
#  |-- verified: boolean (nullable = true)
#  |-- vote: double (nullable = true)
#  |-- reviewText_cleaned: string (nullable = true)
#  |-- summary_cleaned: string (nullable = true)

# %%
df = df.drop("reviewerName")

# %%
#because this data set is large
#only sampe 1% of it
df_sample = df.sample(fraction=0.01, seed=42)

# %%
#df.write.format('json').mode('overwrite').save("drive/MyDrive/Colab_Notebooks/Amazon_reviews/cleaned_data")

# %%
df_sample.write.format('json').mode('overwrite').save("drive/MyDrive/Colab_Notebooks/Amazon_reviews/sample_data")
